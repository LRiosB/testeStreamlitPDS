# %%
import st_pages

# %%
help(st_pages)
# Out:
# Help on package st_pages:
#
# NAME
#     st_pages
#
# PACKAGE CONTENTS
#
#
# CLASSES
#     builtins.object
#         Page
#             Section
#
#     class Page(builtins.object)
#      |  Page(path: 'str', name: 'str | None' = None, icon: 'str | None' = None, is_section: 'bool' = False, in_section: 'bool' = True, use_relative_hash: 'bool' = False) -> None
#      |
#      |  Utility class for working with pages
#      |
#      |  Parameters
#      |  ----------
#      |  path: str
#      |      The path to the page
#      |  name: str (optional)
#      |      The name of the page. If not provided, the name will be inferred from
#      |      the path
#      |  icon: str (optional)
#      |      The icon of the page. If not provided, the icon will be inferred from
#      |      the path
#      |
#      |  Methods defined here:
#      |
#      |  __eq__(self, other)
#      |      Return self==value.
#      |
# ...
